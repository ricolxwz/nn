# %% [markdown]
# <a href="https://www.kaggle.com/code/ricolxwz/transformer-01?scriptVersionId=213638694" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
测试
